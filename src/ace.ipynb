# %%
import os
import sys

os.chdir(r"C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline")



#!{sys.executable} -m src.ingestion.ingest_bts --year 2025 --month 12 --extract

#!{sys.executable} -m src.ingestion.ingest_references --year 2025 --month 12

#!{sys.executable} -m src.transformation.silver_transformation --year 2025 --month 12

# !{sys.executable} -m src.transformation.silver_transformation_references --year 2025 --month 12
# Out:
# Already exists: C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\data\bronze\reference\year=2026\month=06\airlines\L_Airline_ID.csv
# airlines: OK
# Already exists: C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\data\bronze\reference\year=2026\month=06\airports\L_Airport.csv
# airports: OK
# Already exists: C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\data\bronze\reference\year=2026\month=06\airport_ids\L_Airport-ID.csv
# airport_ids: OK
# Bronze rows: 582304
# root
#  |-- Year: integer (nullable = true)
#  |-- Quarter: integer (nullable = true)
#  |-- Month: integer (nullable = true)
#  |-- DayofMonth: integer (nullable = true)
#  |-- DayOfWeek: integer (nullable = true)
#  |-- FlightDate: date (nullable = true)
#  |-- Reporting_Airline: string (nullable = true)
#  |-- DOT_ID_Reporting_Airline: integer (nullable = true)
#  |-- IATA_CODE_Reporting_Airline: string (nullable = true)
# ...
