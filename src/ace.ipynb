# %%
import os
import sys

os.chdir(r"C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline")

#!{sys.executable} -m src.ingestion.ingest_bts --year 2026 --month 6 --extract

#!{sys.executable} -m src.ingestion.ingest_references 

# !{sys.executable} -m src.transformation.silver_transformation --year 2026 --month 3
# Out:
# ERFOLGREICH: Der Prozess mit PID 51376 (untergeordnetem Prozess von PID 41504) wurde beendet.
# ERFOLGREICH: Der Prozess mit PID 41504 (untergeordnetem Prozess von PID 53996) wurde beendet.
# ERFOLGREICH: Der Prozess mit PID 53996 (untergeordnetem Prozess von PID 10988) wurde beendet.
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Traceback (most recent call last):
#   File "<frozen runpy>", line 203, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\src\transformation\silver_transformation.py", line 152, in <module>
#     main()
#     ~~~~^^
#   File "C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\src\transformation\silver_transformation.py", line 149, in main
#     transformation_silver(year, month)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\src\transformation\silver_transformation.py", line 27, in transformation_silver
#     raise FileNotFoundError(
#         f"Bronze directory not found: {input_path}"
#     )
# FileNotFoundError: Bronze directory not found: C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\data\bronze\flights\year=2026\month=03
