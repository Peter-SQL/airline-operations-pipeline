# %%
import os
import sys

os.chdir(r"C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline")

# !{sys.executable} -m src.ingestion.ingest_bts --year 2025 --month 5 --extract

# %%
from src.ingestion.download import get_with_retries
get_with_retries("https://httpbin.org/status/429")
# Out:
# Too many requests — retrying later.
# Waiting 1.31s before retry...
# Too many requests — retrying later.
# Waiting 2.70s before retry...
# Too many requests — retrying later.
# Waiting 4.28s before retry...
# Too many requests — retrying later.
# Waiting 8.97s before retry...
# Too many requests — retrying later.
# Waiting 16.14s before retry...
# All retries exhausted.
