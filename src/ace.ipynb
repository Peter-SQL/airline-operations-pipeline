# %%
import os
import sys

os.chdir(r"C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline")



# !{sys.executable} -m src.ingestion.ingest_bts --year 2025 --month 10 --extract

# !{sys.executable} -m src.ingestion.ingest_references --year 2025 --month 10

# !{sys.executable} -m src.transformation.silver_transformation --year 2025 --month 10

# !{sys.executable} -m src.transformation.silver_transformation_references --year 2025 --month 10

# # für linux dazu und zwar vor der python-zeile: 
# # POSTGRES_HOST=$(awk '/nameserver/ {print $2; exit}' /etc/resolv.conf) \
# # python -m src.loading.load_postgres --year 2025 --month 12

# !{sys.executable} -m src.loading.load_postgres --year 2025 --month 10


# !{sys.executable} -m src.transformation.build_gold --year 2025 --month 10

# !{sys.executable} -m airflow/dags/airline_reliability_pipeline
# Out:
# c:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\.venv\Scripts\python.exe: No module named airflow/dags/airline_reliability_pipeline
