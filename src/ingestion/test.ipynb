# %%
import os
import sys

os.chdir(r"C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline")

# !{sys.executable} -m src.ingestion.ingest_bts --year 2026 --month 3 --extract

# !{sys.executable} -m src.ingestion.ingest_references 

# !{sys.executable} -m src.transformation.silver_transformation --year 2026 --month 3
# Out:
# File 'On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2026_6.zip' already exists in path 'C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\data\bronze\flights\year=2026\month=06'
# Already exists: C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\data\bronze\reference\airlines\L_Airline_ID.csv
# airlines: OK
# Already exists: C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\data\bronze\reference\airports\L_Airport.csv
# airports: OK
# Already exists: C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\data\bronze\reference\airport_ids\L_Airport-ID.csv
# airport_ids: OK
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Traceback (most recent call last):
# ...

# %%
from src.ingestion.ingest_bts import get_with_retries
get_with_retries("https://httpbin.org/status/404")

from src.ingestion.ingest_bts import get_with_retries
get_with_retries("https://httpbin.org/status/429")
# Out:
# File not available yet — retrying.
# Waiting 1.74s before retry...
# File not available yet — retrying.
# Waiting 2.20s before retry...
# File not available yet — retrying.
# Waiting 4.27s before retry...
# File not available yet — retrying.
# Waiting 8.37s before retry...
# File not available yet — retrying.
# Waiting 16.64s before retry...
# All retries exhausted.
# Too many requests — retrying later.
# Waiting 1.10s before retry...
# Too many requests — retrying later.
# Waiting 2.10s before retry...
# Too many requests — retrying later.
# Waiting 4.86s before retry...
# Too many requests — retrying later.
# Waiting 8.19s before retry...
# Too many requests — retrying later.
# Waiting 16.89s before retry...
# All retries exhausted.
