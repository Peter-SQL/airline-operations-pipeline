# %%
import os
import sys

os.chdir(r"C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline")

# !{sys.executable} -m src.ingestion.download --year 1987 --month 12 --extract
# Out:
# File 'On_Time_Reporting_Carrier_On_Time_Performance_1987_present_1987_12.zip' already exists in path 'C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\data\bronze\1987-12'

# %%
 from src.ingestion.download import get_with_retries
 get_with_retries("https://httpbin.org/status/404")
# Out:
# File not available yet — retrying.
# Waiting 1.30s before retry...
# File not available yet — retrying.
# Waiting 2.28s before retry...
# File not available yet — retrying.
# Waiting 4.14s before retry...
# File not available yet — retrying.
# Waiting 8.66s before retry...
# File not available yet — retrying.
# Waiting 16.30s before retry...
# All retries exhausted.
