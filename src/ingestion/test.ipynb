# %%
import os
import sys

os.chdir(r"C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline")

# !{sys.executable} -m src.ingestion.ingest_bts --year 1987 --month 10 --extract
# Out:
# Downloading: https://transtats.bts.gov/prezip/On_Time_Reporting_Carrier_On_Time_Performance_1987_present_1987_10.zip
# Saved: C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\data\bronze\flights\year=1987\month=10\On_Time_Reporting_Carrier_On_Time_Performance_1987_present_1987_10.zip
# ZIP validation successful.
# Extracted to: C:\Users\peter\Documents\greenbootcamps\airline-reliability-pipeline\data\bronze\flights\year=1987\month=10

# %%
 from src.ingestion.download import get_with_retries
 get_with_retries("https://httpbin.org/status/404")
# Out:
# File not available yet — retrying.
# Waiting 1.58s before retry...
# File not available yet — retrying.
# Waiting 2.79s before retry...
# File not available yet — retrying.
# Waiting 4.06s before retry...
# File not available yet — retrying.
# Waiting 8.94s before retry...
# File not available yet — retrying.
# Waiting 16.59s before retry...
# All retries exhausted.
